# %%
# --- load packages ---
import pandas as pd
from pathlib import Path

# --- paths ---
WB = Path("../data/processed/wb_transformed.csv")
FIGS = Path("../reports/figures") # output figures

# --- load ---
wb = pd.read_csv(WB)

# --- checks ---
wb.head(), wb.shape, wb.dtypes
# Out:
# (  country_name country_code  \
#  0  Afghanistan          AFG
#  1  Afghanistan          AFG
#  2  Afghanistan          AFG
#  3  Afghanistan          AFG
#  4  Afghanistan          AFG
#
#                                           series_name     series_code  \
#  0  Electricity production from oil, gas and coal ...  EG.ELC.FOSL.ZS
#  1                       Population growth (annual %)     SP.POP.GROW
#  2                                  Population, total     SP.POP.TOTL
#  3  Renewable energy consumption (% of total final...  EG.FEC.RNEW.ZS
#  4                 Urban population growth (annual %)     SP.URB.GROW
#
#        2000_[yr2000]      2001_[yr2001]     2002_[yr2002]     2003_[yr2003]  \
#  0  6.46268229911353   6.46268229911353  6.46255029718744  19.3691395598403
#  1  1.21217597601851  0.762004896898895  5.25202958527833  6.14519400188515
#  2          20130327           20284307          21378117          22733049
# ...
